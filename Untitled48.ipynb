# %% [markdown]
# #Basic setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import networkx as nx
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %% [markdown]
# #Cora dataset consists of cora.cites and cora.content download

# %%
zip_file = keras.utils.get_file(
    fname="cora.tgz",
    origin="https://linqs-data.soe.ucsc.edu/public/lbc/cora.tgz",
    extract=True,
)
data_dir = os.path.join(os.path.dirname(zip_file), "cora")
# Out:
# Downloading data from https://linqs-data.soe.ucsc.edu/public/lbc/cora.tgz
# 168052/168052 [==============================] - 0s 3us/step

# %%
citations = pd.read_csv(
    os.path.join(data_dir, "cora.cites"),
    sep="\t",
    header=None,
    names=["target", "source"],
)
print("Citations shape:", citations.shape)
# Out:
# Citations shape: (5429, 2)

# %% [markdown]
# # Loaded data into pandas dataframe

# %%
column_names = ["paper_id"] + [f"term_{idx}" for idx in range(1433)] + ["subject"]
papers = pd.read_csv(
    os.path.join(data_dir, "cora.content"), sep="\t", header=None, names=column_names,
)
print("Papers shape:", papers.shape)
# Out:
# Papers shape: (2708, 1435)

# %%
print(papers.sample(5).T)
# Out:
#                             1372                    1515        819   \
# paper_id                  644441                   86359      110164
# term_0                         0                       0           0
# term_1                         0                       0           0
# term_2                         0                       0           0
# term_3                         0                       0           0
# ...                          ...                     ...         ...
# term_1429                      0                       0           0
# term_1430                      0                       0           0
# term_1431                      0                       0           0
# term_1432                      0                       0           0
# subject    Probabilistic_Methods  Reinforcement_Learning  Case_Based
#
#                             376              1592
# paper_id                 1112686            12337
# term_0                         0                0
# term_1                         0                0
# term_2                         0                0
# term_3                         0                0
# ...                          ...              ...
# term_1429                      0                0
# term_1430                      0                0
# term_1431                      0                0
# term_1432                      0                0
# subject    Probabilistic_Methods  Neural_Networks
#
# [1435 rows x 5 columns]

# %% [markdown]
# #Conversion of paper_id and subject_id into zero based indeces

# %%
class_values = sorted(papers["subject"].unique())
class_idx = {name: id for id, name in enumerate(class_values)}
paper_idx = {name: idx for idx, name in enumerate(sorted(papers["paper_id"].unique()))}

papers["paper_id"] = papers["paper_id"].apply(lambda name: paper_idx[name])
citations["source"] = citations["source"].apply(lambda name: paper_idx[name])
citations["target"] = citations["target"].apply(lambda name: paper_idx[name])
papers["subject"] = papers["subject"].apply(lambda value: class_idx[value])

# %%
print(papers.subject.value_counts())
# Out:
# 2    818
# 3    426
# 1    418
# 6    351
# 0    298
# 4    217
# 5    180
# Name: subject, dtype: int64

# %% [markdown]
# #Spilit data into train and test

# %%
train_data, test_data = [], []

for _, group_data in papers.groupby("subject"):
    # Select around 50% of the dataset for training.
    random_selection = np.random.rand(len(group_data.index)) <= 0.5
    train_data.append(group_data[random_selection])
    test_data.append(group_data[~random_selection])

train_data = pd.concat(train_data).sample(frac=1)
test_data = pd.concat(test_data).sample(frac=1)

print("Train data shape:", train_data.shape)
print("Test data shape:", test_data.shape)
# Out:
# Train data shape: (1333, 1435)
# Test data shape: (1375, 1435)

# %% [markdown]
# # Implement train and test experiment

# %%
hidden_units = [32, 32]
learning_rate = 0.01
dropout_rate = 0.5
num_epochs = 300
batch_size = 256

# %%
def run_experiment(model, x_train, y_train):
    # Compile the model.
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate),
        loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[keras.metrics.SparseCategoricalAccuracy(name="acc")],
    )
    # Create an early stopping callback.
    early_stopping = keras.callbacks.EarlyStopping(
        monitor="val_acc", patience=50, restore_best_weights=True
    )
    # Fit the model.
    history = model.fit(
        x=x_train,
        y=y_train,
        epochs=num_epochs,
        batch_size=batch_size,
        validation_split=0.15,
        callbacks=[early_stopping],
    )

    return history

# %%
def display_learning_curves(history):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

    ax1.plot(history.history["loss"])
    ax1.plot(history.history["val_loss"])
    ax1.legend(["train", "test"], loc="upper right")
    ax1.set_xlabel("Epochs")
    ax1.set_ylabel("Loss")

    ax2.plot(history.history["acc"])
    ax2.plot(history.history["val_acc"])
    ax2.legend(["train", "test"], loc="upper right")
    ax2.set_xlabel("Epochs")
    ax2.set_ylabel("Accuracy")
    plt.show()

# %% [markdown]
# #Feed forword network Implementation

# %%
def create_ffn(hidden_units, dropout_rate, name=None):
    fnn_layers = []

    for units in hidden_units:
        fnn_layers.append(layers.BatchNormalization())
        fnn_layers.append(layers.Dropout(dropout_rate))
        fnn_layers.append(layers.Dense(units, activation=tf.nn.gelu))

    return keras.Sequential(fnn_layers, name=name)

# %% [markdown]
# #Prepare dataset for GNN model

# %%
feature_names = set(papers.columns) - {"paper_id", "subject"}
num_features = len(feature_names)
num_classes = len(class_idx)

# Create train and test features as a numpy array.
x_train = train_data[feature_names].to_numpy()
x_test = test_data[feature_names].to_numpy()
# Create train and test targets as a numpy array.
y_train = train_data["subject"]
y_test = test_data["subject"]
# Out:
# <ipython-input-13-5d9edcd08e3d>:6: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   x_train = train_data[feature_names].to_numpy()
# <ipython-input-13-5d9edcd08e3d>:7: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   x_test = test_data[feature_names].to_numpy()

# %%
edges = citations[["source", "target"]].to_numpy().T
# Create an edge weights array of ones.
edge_weights = tf.ones(shape=edges.shape[1])
# Create a node features array of shape [num_nodes, num_features].
node_features = tf.cast(
    papers.sort_values("paper_id")[feature_names].to_numpy(), dtype=tf.dtypes.float32
)
# Create graph info tuple with node_features, edges, and edge_weights.
graph_info = (node_features, edges, edge_weights)

print("Edges shape:", edges.shape)
print("Nodes shape:", node_features.shape)
# Out:
# Edges shape: (2, 5429)
# Nodes shape: (2708, 1433)
# <ipython-input-14-c809720035fd>:6: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   papers.sort_values("paper_id")[feature_names].to_numpy(), dtype=tf.dtypes.float32

# %% [markdown]
# #Implement a graph convolution layer

# %%
class GraphConvLayer(layers.Layer):
    def __init__(
        self,
        hidden_units,
        dropout_rate=0.2,
        aggregation_type="mean",
        combination_type="concat",
        normalize=False,
        *args,
        **kwargs,
    ):
        super().__init__(*args, **kwargs)

        self.aggregation_type = aggregation_type
        self.combination_type = combination_type
        self.normalize = normalize

        self.ffn_prepare = create_ffn(hidden_units, dropout_rate)
        if self.combination_type == "gated":
            self.update_fn = layers.GRU(
                units=hidden_units,
                activation="tanh",
                recurrent_activation="sigmoid",
                dropout=dropout_rate,
                return_state=True,
                recurrent_dropout=dropout_rate,
            )
        else:
            self.update_fn = create_ffn(hidden_units, dropout_rate)

    def prepare(self, node_repesentations, weights=None):
        # node_repesentations shape is [num_edges, embedding_dim].
        messages = self.ffn_prepare(node_repesentations)
        if weights is not None:
            messages = messages * tf.expand_dims(weights, -1)
        return messages

    def aggregate(self, node_indices, neighbour_messages, node_repesentations):
        # node_indices shape is [num_edges].
        # neighbour_messages shape: [num_edges, representation_dim].
        # node_repesentations shape is [num_nodes, representation_dim]
        num_nodes = node_repesentations.shape[0]
        if self.aggregation_type == "sum":
            aggregated_message = tf.math.unsorted_segment_sum(
                neighbour_messages, node_indices, num_segments=num_nodes
            )
        elif self.aggregation_type == "mean":
            aggregated_message = tf.math.unsorted_segment_mean(
                neighbour_messages, node_indices, num_segments=num_nodes
            )
        elif self.aggregation_type == "max":
            aggregated_message = tf.math.unsorted_segment_max(
                neighbour_messages, node_indices, num_segments=num_nodes
            )
        else:
            raise ValueError(f"Invalid aggregation type: {self.aggregation_type}.")

        return aggregated_message

    def update(self, node_repesentations, aggregated_messages):
        # node_repesentations shape is [num_nodes, representation_dim].
        # aggregated_messages shape is [num_nodes, representation_dim].
        if self.combination_type == "gru":
            # Create a sequence of two elements for the GRU layer.
            h = tf.stack([node_repesentations, aggregated_messages], axis=1)
        elif self.combination_type == "concat":
            # Concatenate the node_repesentations and aggregated_messages.
            h = tf.concat([node_repesentations, aggregated_messages], axis=1)
        elif self.combination_type == "add":
            # Add node_repesentations and aggregated_messages.
            h = node_repesentations + aggregated_messages
        else:
            raise ValueError(f"Invalid combination type: {self.combination_type}.")

        # Apply the processing function.
        node_embeddings = self.update_fn(h)
        if self.combination_type == "gru":
            node_embeddings = tf.unstack(node_embeddings, axis=1)[-1]

        if self.normalize:
            node_embeddings = tf.nn.l2_normalize(node_embeddings, axis=-1)
        return node_embeddings

    def call(self, inputs):
        """Process the inputs to produce the node_embeddings.

        inputs: a tuple of three elements: node_repesentations, edges, edge_weights.
        Returns: node_embeddings of shape [num_nodes, representation_dim].
        """

        node_repesentations, edges, edge_weights = inputs
        # Get node_indices (source) and neighbour_indices (target) from edges.
        node_indices, neighbour_indices = edges[0], edges[1]
        # neighbour_repesentations shape is [num_edges, representation_dim].
        neighbour_repesentations = tf.gather(node_repesentations, neighbour_indices)

        # Prepare the messages of the neighbours.
        neighbour_messages = self.prepare(neighbour_repesentations, edge_weights)
        # Aggregate the neighbour messages.
        aggregated_messages = self.aggregate(
            node_indices, neighbour_messages, node_repesentations
        )
        # Update the node embedding with the neighbour messages.
        return self.update(node_repesentations, aggregated_messages)

# %% [markdown]
# #implement a GNN classifier

# %%
class GNNNodeClassifier(tf.keras.Model):
    def __init__(
        self,
        graph_info,
        num_classes,
        hidden_units,
        aggregation_type="sum",
        combination_type="concat",
        dropout_rate=0.2,
        normalize=True,
        *args,
        **kwargs,
    ):
        super().__init__(*args, **kwargs)

        # Unpack graph_info to three elements: node_features, edges, and edge_weight.
        node_features, edges, edge_weights = graph_info
        self.node_features = node_features
        self.edges = edges
        self.edge_weights = edge_weights
        # Set edge_weights to ones if not provided.
        if self.edge_weights is None:
            self.edge_weights = tf.ones(shape=edges.shape[1])
        # Scale edge_weights to sum to 1.
        self.edge_weights = self.edge_weights / tf.math.reduce_sum(self.edge_weights)

        # Create a process layer.
        self.preprocess = create_ffn(hidden_units, dropout_rate, name="preprocess")
        # Create the first GraphConv layer.
        self.conv1 = GraphConvLayer(
            hidden_units,
            dropout_rate,
            aggregation_type,
            combination_type,
            normalize,
            name="graph_conv1",
        )
        # Create the second GraphConv layer.
        self.conv2 = GraphConvLayer(
            hidden_units,
            dropout_rate,
            aggregation_type,
            combination_type,
            normalize,
            name="graph_conv2",
        )
        # Create a postprocess layer.
        self.postprocess = create_ffn(hidden_units, dropout_rate, name="postprocess")
        # Create a compute logits layer.
        self.compute_logits = layers.Dense(units=num_classes, name="logits")

    def call(self, input_node_indices):
        # Preprocess the node_features to produce node representations.
        x = self.preprocess(self.node_features)
        # Apply the first graph conv layer.
        x1 = self.conv1((x, self.edges, self.edge_weights))
        # Skip connection.
        x = x1 + x
        # Apply the second graph conv layer.
        x2 = self.conv2((x, self.edges, self.edge_weights))
        # Skip connection.
        x = x2 + x
        # Postprocess node embedding.
        x = self.postprocess(x)
        # Fetch node embeddings for the input node_indices.
        node_embeddings = tf.gather(x, input_node_indices)
        # Compute logits
        return self.compute_logits(node_embeddings)

# %% [markdown]
# #Train the GNN model

# %%
gnn_model = GNNNodeClassifier(
    graph_info=graph_info,
    num_classes=num_classes,
    hidden_units=hidden_units,
    dropout_rate=dropout_rate,
    name="gnn_model",
)

print("GNN output shape:", gnn_model([1, 10, 100]))

gnn_model.summary()
# Out:
# GNN output shape: tf.Tensor(
# [[-0.02574421 -0.00549514 -0.09570985 -0.00328016  0.02298828  0.01693214
#   -0.1060608 ]
#  [-0.16365993  0.19020168 -0.04211573  0.04013416 -0.12126335 -0.04199585
#    0.02532306]
#  [-0.14894502 -0.04258403  0.03334758  0.00568793  0.02807028  0.09591709
#    0.00551692]], shape=(3, 7), dtype=float32)
# Model: "gnn_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  preprocess (Sequential)     (2708, 32)                52804
#
#  graph_conv1 (GraphConvLayer  multiple                 5888
#  )
#
#  graph_conv2 (GraphConvLayer  multiple                 5888
#  )
#
#  postprocess (Sequential)    (2708, 32)                2368
#
#  logits (Dense)              multiple                  231
#
# =================================================================
# Total params: 67,179
# Trainable params: 63,481
# Non-trainable params: 3,698
# _________________________________________________________________

# %%
x_train = train_data.paper_id.to_numpy()
history = run_experiment(gnn_model, x_train, y_train)
# Out:
# Epoch 1/300
# 5/5 [==============================] - 21s 882ms/step - loss: 2.2847 - acc: 0.1730 - val_loss: 1.9106 - val_acc: 0.2950
# Epoch 2/300
# 5/5 [==============================] - 2s 409ms/step - loss: 2.0115 - acc: 0.2339 - val_loss: 1.8997 - val_acc: 0.3150
# Epoch 3/300
# 5/5 [==============================] - 2s 339ms/step - loss: 1.9378 - acc: 0.2445 - val_loss: 1.8928 - val_acc: 0.3150
# Epoch 4/300
# 5/5 [==============================] - 2s 405ms/step - loss: 1.8814 - acc: 0.2595 - val_loss: 1.8772 - val_acc: 0.3150
# Epoch 5/300
# 5/5 [==============================] - 2s 320ms/step - loss: 1.8649 - acc: 0.2851 - val_loss: 1.8628 - val_acc: 0.3150
# Epoch 6/300
# 5/5 [==============================] - 2s 373ms/step - loss: 1.8390 - acc: 0.2754 - val_loss: 1.8559 - val_acc: 0.3150
# Epoch 7/300
# 5/5 [==============================] - 3s 569ms/step - loss: 1.8272 - acc: 0.2877 - val_loss: 1.8350 - val_acc: 0.3150
# Epoch 8/300
# 5/5 [==============================] - 2s 344ms/step - loss: 1.8166 - acc: 0.2921 - val_loss: 1.8178 - val_acc: 0.3150
# Epoch 9/300
# 5/5 [==============================] - 2s 326ms/step - loss: 1.7989 - acc: 0.3036 - val_loss: 1.7892 - val_acc: 0.3150
# Epoch 10/300
# 5/5 [==============================] - 2s 360ms/step - loss: 1.7852 - acc: 0.3045 - val_loss: 1.7440 - val_acc: 0.3150
# Epoch 11/300
# 5/5 [==============================] - 2s 298ms/step - loss: 1.7527 - acc: 0.2983 - val_loss: 1.6934 - val_acc: 0.3250
# Epoch 12/300
# 5/5 [==============================] - 2s 371ms/step - loss: 1.7323 - acc: 0.3195 - val_loss: 1.6352 - val_acc: 0.3300
# Epoch 13/300
# 5/5 [==============================] - 1s 239ms/step - loss: 1.7123 - acc: 0.3336 - val_loss: 1.5816 - val_acc: 0.3800
# Epoch 14/300
# 5/5 [==============================] - 1s 261ms/step - loss: 1.6716 - acc: 0.3539 - val_loss: 1.5377 - val_acc: 0.4000
# Epoch 15/300
# 5/5 [==============================] - 2s 312ms/step - loss: 1.6216 - acc: 0.3689 - val_loss: 1.5188 - val_acc: 0.4050
# Epoch 16/300
# 5/5 [==============================] - 1s 216ms/step - loss: 1.5767 - acc: 0.3945 - val_loss: 1.5965 - val_acc: 0.4150
# Epoch 17/300
# 5/5 [==============================] - 1s 178ms/step - loss: 1.5392 - acc: 0.4175 - val_loss: 1.5494 - val_acc: 0.4250
# Epoch 18/300
# 5/5 [==============================] - 1s 176ms/step - loss: 1.4880 - acc: 0.4051 - val_loss: 1.5035 - val_acc: 0.4250
# Epoch 19/300
# 5/5 [==============================] - 1s 181ms/step - loss: 1.4794 - acc: 0.4378 - val_loss: 1.4805 - val_acc: 0.4550
# Epoch 20/300
# 5/5 [==============================] - 1s 176ms/step - loss: 1.4775 - acc: 0.4510 - val_loss: 1.4200 - val_acc: 0.4800
# Epoch 21/300
# 5/5 [==============================] - 1s 185ms/step - loss: 1.4043 - acc: 0.4598 - val_loss: 1.3780 - val_acc: 0.5150
# Epoch 22/300
# 5/5 [==============================] - 1s 180ms/step - loss: 1.3859 - acc: 0.4881 - val_loss: 1.3407 - val_acc: 0.5050
# Epoch 23/300
# 5/5 [==============================] - 1s 179ms/step - loss: 1.3405 - acc: 0.4978 - val_loss: 1.2944 - val_acc: 0.5350
# Epoch 24/300
# 5/5 [==============================] - 1s 183ms/step - loss: 1.3132 - acc: 0.5216 - val_loss: 1.2527 - val_acc: 0.5500
# Epoch 25/300
# 5/5 [==============================] - 1s 186ms/step - loss: 1.2488 - acc: 0.5543 - val_loss: 1.2108 - val_acc: 0.5650
# Epoch 26/300
# 5/5 [==============================] - 1s 180ms/step - loss: 1.2373 - acc: 0.5375 - val_loss: 1.1832 - val_acc: 0.5700
# Epoch 27/300
# 5/5 [==============================] - 1s 255ms/step - loss: 1.1847 - acc: 0.5596 - val_loss: 1.2353 - val_acc: 0.5600
# Epoch 28/300
# 5/5 [==============================] - 2s 306ms/step - loss: 1.1689 - acc: 0.5772 - val_loss: 1.4502 - val_acc: 0.5550
# Epoch 29/300
# 5/5 [==============================] - 1s 209ms/step - loss: 1.1490 - acc: 0.5746 - val_loss: 1.6171 - val_acc: 0.5500
# Epoch 30/300
# 5/5 [==============================] - 1s 175ms/step - loss: 1.1313 - acc: 0.6028 - val_loss: 1.4017 - val_acc: 0.5600
# Epoch 31/300
# 5/5 [==============================] - 1s 187ms/step - loss: 1.0464 - acc: 0.6214 - val_loss: 1.3119 - val_acc: 0.5750
# Epoch 32/300
# 5/5 [==============================] - 1s 191ms/step - loss: 1.0500 - acc: 0.6417 - val_loss: 1.3840 - val_acc: 0.5700
# Epoch 33/300
# 5/5 [==============================] - 1s 185ms/step - loss: 1.0450 - acc: 0.6161 - val_loss: 1.3275 - val_acc: 0.5800
# Epoch 34/300
# 5/5 [==============================] - 2s 320ms/step - loss: 1.0337 - acc: 0.6390 - val_loss: 1.2432 - val_acc: 0.6100
# Epoch 35/300
# 5/5 [==============================] - 2s 330ms/step - loss: 0.9668 - acc: 0.6655 - val_loss: 1.1107 - val_acc: 0.6600
# Epoch 36/300
# 5/5 [==============================] - 2s 315ms/step - loss: 0.9167 - acc: 0.6787 - val_loss: 1.1014 - val_acc: 0.6450
# Epoch 37/300
# 5/5 [==============================] - 2s 364ms/step - loss: 0.8751 - acc: 0.7052 - val_loss: 1.0752 - val_acc: 0.6450
# Epoch 38/300
# 5/5 [==============================] - 2s 498ms/step - loss: 0.8838 - acc: 0.6902 - val_loss: 1.0681 - val_acc: 0.6500
# Epoch 39/300
# 5/5 [==============================] - 2s 366ms/step - loss: 0.9068 - acc: 0.6884 - val_loss: 1.0031 - val_acc: 0.6650
# Epoch 40/300
# 5/5 [==============================] - 2s 372ms/step - loss: 0.8892 - acc: 0.7017 - val_loss: 0.9664 - val_acc: 0.6950
# Epoch 41/300
# 5/5 [==============================] - 2s 382ms/step - loss: 0.8895 - acc: 0.7096 - val_loss: 0.9602 - val_acc: 0.6900
# Epoch 42/300
# 5/5 [==============================] - 2s 345ms/step - loss: 0.7890 - acc: 0.7423 - val_loss: 0.9261 - val_acc: 0.6800
# Epoch 43/300
# 5/5 [==============================] - 1s 239ms/step - loss: 0.8442 - acc: 0.7308 - val_loss: 0.8998 - val_acc: 0.6600
# Epoch 44/300
# 5/5 [==============================] - 1s 186ms/step - loss: 0.8207 - acc: 0.7299 - val_loss: 0.8992 - val_acc: 0.6750
# Epoch 45/300
# 5/5 [==============================] - 1s 235ms/step - loss: 0.8111 - acc: 0.7211 - val_loss: 0.8851 - val_acc: 0.7100
# Epoch 46/300
# 5/5 [==============================] - 2s 311ms/step - loss: 0.8310 - acc: 0.7255 - val_loss: 0.9225 - val_acc: 0.7050
# Epoch 47/300
# 5/5 [==============================] - 1s 231ms/step - loss: 0.7366 - acc: 0.7590 - val_loss: 0.8615 - val_acc: 0.7050
# Epoch 48/300
# 5/5 [==============================] - 1s 190ms/step - loss: 0.7798 - acc: 0.7493 - val_loss: 0.8766 - val_acc: 0.7000
# Epoch 49/300
# 5/5 [==============================] - 1s 182ms/step - loss: 0.7826 - acc: 0.7308 - val_loss: 1.0335 - val_acc: 0.6500
# Epoch 50/300
# 5/5 [==============================] - 1s 178ms/step - loss: 0.7110 - acc: 0.7723 - val_loss: 1.0032 - val_acc: 0.6650
# Epoch 51/300
# 5/5 [==============================] - 1s 186ms/step - loss: 0.7150 - acc: 0.7643 - val_loss: 0.8703 - val_acc: 0.7200
# Epoch 52/300
# 5/5 [==============================] - 1s 178ms/step - loss: 0.7164 - acc: 0.7661 - val_loss: 0.8070 - val_acc: 0.7350
# Epoch 53/300
# 5/5 [==============================] - 1s 191ms/step - loss: 0.7178 - acc: 0.7520 - val_loss: 0.8180 - val_acc: 0.7400
# Epoch 54/300
# 5/5 [==============================] - 1s 173ms/step - loss: 0.7207 - acc: 0.7546 - val_loss: 0.8373 - val_acc: 0.7250
# Epoch 55/300
# 5/5 [==============================] - 1s 185ms/step - loss: 0.6584 - acc: 0.7908 - val_loss: 0.7965 - val_acc: 0.7350
# Epoch 56/300
# 5/5 [==============================] - 1s 184ms/step - loss: 0.6386 - acc: 0.7908 - val_loss: 0.7771 - val_acc: 0.7450
# Epoch 57/300
# 5/5 [==============================] - 1s 187ms/step - loss: 0.5968 - acc: 0.8129 - val_loss: 0.7577 - val_acc: 0.7450
# Epoch 58/300
# 5/5 [==============================] - 1s 240ms/step - loss: 0.6584 - acc: 0.7873 - val_loss: 0.7749 - val_acc: 0.7350
# Epoch 59/300
# 5/5 [==============================] - 1s 299ms/step - loss: 0.6173 - acc: 0.7873 - val_loss: 0.7533 - val_acc: 0.7300
# Epoch 60/300
# 5/5 [==============================] - 1s 213ms/step - loss: 0.6679 - acc: 0.7864 - val_loss: 0.7521 - val_acc: 0.7350
# Epoch 61/300
# 5/5 [==============================] - 1s 174ms/step - loss: 0.5834 - acc: 0.8191 - val_loss: 0.7453 - val_acc: 0.7450
# Epoch 62/300
# 5/5 [==============================] - 1s 174ms/step - loss: 0.6591 - acc: 0.7873 - val_loss: 0.7113 - val_acc: 0.7600
# Epoch 63/300
# 5/5 [==============================] - 1s 173ms/step - loss: 0.6116 - acc: 0.7891 - val_loss: 0.6957 - val_acc: 0.7550
# Epoch 64/300
# 5/5 [==============================] - 1s 175ms/step - loss: 0.6404 - acc: 0.7926 - val_loss: 0.7341 - val_acc: 0.7450
# Epoch 65/300
# 5/5 [==============================] - 1s 173ms/step - loss: 0.6235 - acc: 0.7979 - val_loss: 0.7464 - val_acc: 0.7500
# Epoch 66/300
# 5/5 [==============================] - 1s 189ms/step - loss: 0.5873 - acc: 0.8023 - val_loss: 0.7382 - val_acc: 0.7500
# Epoch 67/300
# 5/5 [==============================] - 1s 178ms/step - loss: 0.6297 - acc: 0.7855 - val_loss: 0.7792 - val_acc: 0.7300
# Epoch 68/300
# 5/5 [==============================] - 1s 189ms/step - loss: 0.6001 - acc: 0.7988 - val_loss: 0.7574 - val_acc: 0.7400
# Epoch 69/300
# 5/5 [==============================] - 1s 188ms/step - loss: 0.5681 - acc: 0.8164 - val_loss: 0.7398 - val_acc: 0.7650
# Epoch 70/300
# 5/5 [==============================] - 1s 174ms/step - loss: 0.5494 - acc: 0.8199 - val_loss: 0.7111 - val_acc: 0.7600
# Epoch 71/300
# 5/5 [==============================] - 1s 214ms/step - loss: 0.5643 - acc: 0.8129 - val_loss: 0.6907 - val_acc: 0.7700
# Epoch 72/300
# 5/5 [==============================] - 2s 313ms/step - loss: 0.5704 - acc: 0.8155 - val_loss: 0.6933 - val_acc: 0.7750
# Epoch 73/300
# 5/5 [==============================] - 1s 231ms/step - loss: 0.5201 - acc: 0.8279 - val_loss: 0.7031 - val_acc: 0.7650
# Epoch 74/300
# 5/5 [==============================] - 1s 181ms/step - loss: 0.6000 - acc: 0.8111 - val_loss: 0.6509 - val_acc: 0.7950
# Epoch 75/300
# 5/5 [==============================] - 1s 175ms/step - loss: 0.5124 - acc: 0.8341 - val_loss: 0.6672 - val_acc: 0.7750
# Epoch 76/300
# 5/5 [==============================] - 1s 176ms/step - loss: 0.5370 - acc: 0.8173 - val_loss: 0.7020 - val_acc: 0.7650
# Epoch 77/300
# 5/5 [==============================] - 1s 186ms/step - loss: 0.5152 - acc: 0.8385 - val_loss: 0.7399 - val_acc: 0.7650
# Epoch 78/300
# 5/5 [==============================] - 1s 187ms/step - loss: 0.5075 - acc: 0.8350 - val_loss: 0.6954 - val_acc: 0.7850
# Epoch 79/300
# 5/5 [==============================] - 1s 179ms/step - loss: 0.5443 - acc: 0.8235 - val_loss: 0.6900 - val_acc: 0.7650
# Epoch 80/300
# 5/5 [==============================] - 1s 187ms/step - loss: 0.5549 - acc: 0.8279 - val_loss: 0.6650 - val_acc: 0.7800
# Epoch 81/300
# 5/5 [==============================] - 1s 177ms/step - loss: 0.5258 - acc: 0.8332 - val_loss: 0.6789 - val_acc: 0.7650
# Epoch 82/300
# 5/5 [==============================] - 1s 177ms/step - loss: 0.4842 - acc: 0.8376 - val_loss: 0.6814 - val_acc: 0.7850
# Epoch 83/300
# 5/5 [==============================] - 1s 185ms/step - loss: 0.4858 - acc: 0.8332 - val_loss: 0.6961 - val_acc: 0.7600
# Epoch 84/300
# 5/5 [==============================] - 1s 199ms/step - loss: 0.4686 - acc: 0.8482 - val_loss: 0.7619 - val_acc: 0.7800
# Epoch 85/300
# 5/5 [==============================] - 1s 303ms/step - loss: 0.4574 - acc: 0.8526 - val_loss: 0.8200 - val_acc: 0.7600
# Epoch 86/300
# 5/5 [==============================] - 1s 270ms/step - loss: 0.5265 - acc: 0.8341 - val_loss: 0.8321 - val_acc: 0.7450
# Epoch 87/300
# 5/5 [==============================] - 2s 327ms/step - loss: 0.5003 - acc: 0.8376 - val_loss: 0.7973 - val_acc: 0.7300
# Epoch 88/300
# 5/5 [==============================] - 1s 184ms/step - loss: 0.4786 - acc: 0.8350 - val_loss: 0.8046 - val_acc: 0.7300
# Epoch 89/300
# 5/5 [==============================] - 1s 176ms/step - loss: 0.5184 - acc: 0.8367 - val_loss: 0.7534 - val_acc: 0.7600
# Epoch 90/300
# 5/5 [==============================] - 1s 184ms/step - loss: 0.5085 - acc: 0.8358 - val_loss: 0.6667 - val_acc: 0.7850
# Epoch 91/300
# 5/5 [==============================] - 1s 170ms/step - loss: 0.4953 - acc: 0.8455 - val_loss: 0.6622 - val_acc: 0.7950
# Epoch 92/300
# 5/5 [==============================] - 1s 181ms/step - loss: 0.4494 - acc: 0.8579 - val_loss: 0.6756 - val_acc: 0.7850
# Epoch 93/300
# 5/5 [==============================] - 1s 188ms/step - loss: 0.4807 - acc: 0.8394 - val_loss: 0.7104 - val_acc: 0.7750
# Epoch 94/300
# 5/5 [==============================] - 1s 178ms/step - loss: 0.4954 - acc: 0.8482 - val_loss: 0.6988 - val_acc: 0.7850
# Epoch 95/300
# 5/5 [==============================] - 1s 192ms/step - loss: 0.4657 - acc: 0.8561 - val_loss: 0.6862 - val_acc: 0.8100
# Epoch 96/300
# 5/5 [==============================] - 1s 188ms/step - loss: 0.4710 - acc: 0.8579 - val_loss: 0.6978 - val_acc: 0.7950
# Epoch 97/300
# 5/5 [==============================] - 1s 307ms/step - loss: 0.4668 - acc: 0.8385 - val_loss: 0.7368 - val_acc: 0.7850
# Epoch 98/300
# 5/5 [==============================] - 1s 279ms/step - loss: 0.4732 - acc: 0.8385 - val_loss: 0.7321 - val_acc: 0.7850
# Epoch 99/300
# 5/5 [==============================] - 1s 176ms/step - loss: 0.4965 - acc: 0.8526 - val_loss: 0.7054 - val_acc: 0.7850
# Epoch 100/300
# 5/5 [==============================] - 1s 182ms/step - loss: 0.4413 - acc: 0.8614 - val_loss: 0.7148 - val_acc: 0.7750
# Epoch 101/300
# 5/5 [==============================] - 1s 186ms/step - loss: 0.4436 - acc: 0.8756 - val_loss: 0.6836 - val_acc: 0.7850
# Epoch 102/300
# 5/5 [==============================] - 1s 178ms/step - loss: 0.4611 - acc: 0.8535 - val_loss: 0.6849 - val_acc: 0.7850
# Epoch 103/300
# 5/5 [==============================] - 1s 187ms/step - loss: 0.5034 - acc: 0.8394 - val_loss: 0.6835 - val_acc: 0.7850
# Epoch 104/300
# 5/5 [==============================] - 1s 181ms/step - loss: 0.4672 - acc: 0.8491 - val_loss: 0.6746 - val_acc: 0.7900
# Epoch 105/300
# 5/5 [==============================] - 1s 179ms/step - loss: 0.5034 - acc: 0.8288 - val_loss: 0.6509 - val_acc: 0.7900
# Epoch 106/300
# 5/5 [==============================] - 1s 188ms/step - loss: 0.4325 - acc: 0.8597 - val_loss: 0.6700 - val_acc: 0.7800
# Epoch 107/300
# 5/5 [==============================] - 1s 186ms/step - loss: 0.4653 - acc: 0.8517 - val_loss: 0.7009 - val_acc: 0.7700
# Epoch 108/300
# 5/5 [==============================] - 1s 174ms/step - loss: 0.4959 - acc: 0.8517 - val_loss: 0.6783 - val_acc: 0.7900
# Epoch 109/300
# 5/5 [==============================] - 1s 192ms/step - loss: 0.4607 - acc: 0.8517 - val_loss: 0.6787 - val_acc: 0.8050
# Epoch 110/300
# 5/5 [==============================] - 2s 318ms/step - loss: 0.4667 - acc: 0.8526 - val_loss: 0.6991 - val_acc: 0.8100
# Epoch 111/300
# 5/5 [==============================] - 1s 265ms/step - loss: 0.4640 - acc: 0.8500 - val_loss: 0.7051 - val_acc: 0.8100
# Epoch 112/300
# 5/5 [==============================] - 1s 176ms/step - loss: 0.4355 - acc: 0.8623 - val_loss: 0.6674 - val_acc: 0.7900
# Epoch 113/300
# 5/5 [==============================] - 1s 182ms/step - loss: 0.4073 - acc: 0.8703 - val_loss: 0.6643 - val_acc: 0.8100
# Epoch 114/300
# 5/5 [==============================] - 1s 182ms/step - loss: 0.4048 - acc: 0.8729 - val_loss: 0.6706 - val_acc: 0.8100
# Epoch 115/300
# 5/5 [==============================] - 1s 182ms/step - loss: 0.4821 - acc: 0.8508 - val_loss: 0.6584 - val_acc: 0.8200
# Epoch 116/300
# 5/5 [==============================] - 1s 223ms/step - loss: 0.3765 - acc: 0.8729 - val_loss: 0.6637 - val_acc: 0.8050
# Epoch 117/300
# 5/5 [==============================] - 2s 368ms/step - loss: 0.3905 - acc: 0.8747 - val_loss: 0.6515 - val_acc: 0.8200
# Epoch 118/300
# 5/5 [==============================] - 1s 300ms/step - loss: 0.4250 - acc: 0.8632 - val_loss: 0.6543 - val_acc: 0.8200
# Epoch 119/300
# 5/5 [==============================] - 3s 609ms/step - loss: 0.4431 - acc: 0.8588 - val_loss: 0.7031 - val_acc: 0.8100
# Epoch 120/300
# 5/5 [==============================] - 3s 614ms/step - loss: 0.3962 - acc: 0.8641 - val_loss: 0.7328 - val_acc: 0.7900
# Epoch 121/300
# 5/5 [==============================] - 2s 357ms/step - loss: 0.3966 - acc: 0.8817 - val_loss: 0.7048 - val_acc: 0.8150
# Epoch 122/300
# 5/5 [==============================] - 2s 305ms/step - loss: 0.4090 - acc: 0.8720 - val_loss: 0.6861 - val_acc: 0.8100
# Epoch 123/300
# 5/5 [==============================] - 2s 373ms/step - loss: 0.4146 - acc: 0.8561 - val_loss: 0.6828 - val_acc: 0.8200
# Epoch 124/300
# 5/5 [==============================] - 2s 368ms/step - loss: 0.4049 - acc: 0.8747 - val_loss: 0.6775 - val_acc: 0.8300
# Epoch 125/300
# 5/5 [==============================] - 1s 286ms/step - loss: 0.4080 - acc: 0.8756 - val_loss: 0.6651 - val_acc: 0.8300
# Epoch 126/300
# 5/5 [==============================] - 1s 243ms/step - loss: 0.3783 - acc: 0.8817 - val_loss: 0.6560 - val_acc: 0.8350
# Epoch 127/300
# 5/5 [==============================] - 2s 312ms/step - loss: 0.4234 - acc: 0.8747 - val_loss: 0.6511 - val_acc: 0.8450
# Epoch 128/300
# 5/5 [==============================] - 1s 234ms/step - loss: 0.4134 - acc: 0.8729 - val_loss: 0.6732 - val_acc: 0.8200
# Epoch 129/300
# 5/5 [==============================] - 1s 176ms/step - loss: 0.3885 - acc: 0.8808 - val_loss: 0.7082 - val_acc: 0.7950
# Epoch 130/300
# 5/5 [==============================] - 1s 187ms/step - loss: 0.3887 - acc: 0.8738 - val_loss: 0.7083 - val_acc: 0.8100
# Epoch 131/300
# 5/5 [==============================] - 1s 175ms/step - loss: 0.3819 - acc: 0.8782 - val_loss: 0.6713 - val_acc: 0.8100
# Epoch 132/300
# 5/5 [==============================] - 1s 189ms/step - loss: 0.3962 - acc: 0.8738 - val_loss: 0.6719 - val_acc: 0.8250
# Epoch 133/300
# 5/5 [==============================] - 1s 175ms/step - loss: 0.3752 - acc: 0.8853 - val_loss: 0.7058 - val_acc: 0.8150
# Epoch 134/300
# 5/5 [==============================] - 1s 185ms/step - loss: 0.4014 - acc: 0.8844 - val_loss: 0.6893 - val_acc: 0.8050
# Epoch 135/300
# 5/5 [==============================] - 1s 176ms/step - loss: 0.3963 - acc: 0.8658 - val_loss: 0.6816 - val_acc: 0.8300
# Epoch 136/300
# 5/5 [==============================] - 1s 175ms/step - loss: 0.3777 - acc: 0.8764 - val_loss: 0.7122 - val_acc: 0.8350
# Epoch 137/300
# 5/5 [==============================] - 1s 183ms/step - loss: 0.3940 - acc: 0.8826 - val_loss: 0.7209 - val_acc: 0.8250
# Epoch 138/300
# 5/5 [==============================] - 1s 186ms/step - loss: 0.3707 - acc: 0.8853 - val_loss: 0.7178 - val_acc: 0.8300
# Epoch 139/300
# 5/5 [==============================] - 1s 256ms/step - loss: 0.3978 - acc: 0.8835 - val_loss: 0.6963 - val_acc: 0.8350
# Epoch 140/300
# 5/5 [==============================] - 2s 312ms/step - loss: 0.3439 - acc: 0.8967 - val_loss: 0.6720 - val_acc: 0.8200
# Epoch 141/300
# 5/5 [==============================] - 1s 206ms/step - loss: 0.3705 - acc: 0.8826 - val_loss: 0.6719 - val_acc: 0.8250
# Epoch 142/300
# 5/5 [==============================] - 1s 194ms/step - loss: 0.4301 - acc: 0.8729 - val_loss: 0.6615 - val_acc: 0.8300
# Epoch 143/300
# 5/5 [==============================] - 1s 184ms/step - loss: 0.3932 - acc: 0.8711 - val_loss: 0.6526 - val_acc: 0.8300
# Epoch 144/300
# 5/5 [==============================] - 1s 179ms/step - loss: 0.3845 - acc: 0.8844 - val_loss: 0.6513 - val_acc: 0.8250
# Epoch 145/300
# 5/5 [==============================] - 1s 176ms/step - loss: 0.3937 - acc: 0.8800 - val_loss: 0.6677 - val_acc: 0.8300
# Epoch 146/300
# 5/5 [==============================] - 1s 183ms/step - loss: 0.3469 - acc: 0.8897 - val_loss: 0.6493 - val_acc: 0.8400
# Epoch 147/300
# 5/5 [==============================] - 1s 191ms/step - loss: 0.3961 - acc: 0.8667 - val_loss: 0.6776 - val_acc: 0.8300
# Epoch 148/300
# 5/5 [==============================] - 1s 177ms/step - loss: 0.4000 - acc: 0.8685 - val_loss: 0.6569 - val_acc: 0.8300
# Epoch 149/300
# 5/5 [==============================] - 1s 188ms/step - loss: 0.3657 - acc: 0.8835 - val_loss: 0.6423 - val_acc: 0.8350
# Epoch 150/300
# 5/5 [==============================] - 1s 180ms/step - loss: 0.3536 - acc: 0.8976 - val_loss: 0.6456 - val_acc: 0.8400
# Epoch 151/300
# 5/5 [==============================] - 1s 187ms/step - loss: 0.3474 - acc: 0.8994 - val_loss: 0.6276 - val_acc: 0.8350
# Epoch 152/300
# 5/5 [==============================] - 1s 245ms/step - loss: 0.3784 - acc: 0.8835 - val_loss: 0.6777 - val_acc: 0.8300
# Epoch 153/300
# 5/5 [==============================] - 2s 307ms/step - loss: 0.3889 - acc: 0.8914 - val_loss: 0.6847 - val_acc: 0.8400
# Epoch 154/300
# 5/5 [==============================] - 1s 209ms/step - loss: 0.4320 - acc: 0.8773 - val_loss: 0.6768 - val_acc: 0.8100
# Epoch 155/300
# 5/5 [==============================] - 1s 186ms/step - loss: 0.3721 - acc: 0.8764 - val_loss: 0.6918 - val_acc: 0.8050
# Epoch 156/300
# 5/5 [==============================] - 1s 191ms/step - loss: 0.3702 - acc: 0.8870 - val_loss: 0.6962 - val_acc: 0.8050
# Epoch 157/300
# 5/5 [==============================] - 1s 181ms/step - loss: 0.4028 - acc: 0.8667 - val_loss: 0.7059 - val_acc: 0.8250
# Epoch 158/300
# 5/5 [==============================] - 1s 192ms/step - loss: 0.3918 - acc: 0.8808 - val_loss: 0.6831 - val_acc: 0.8200
# Epoch 159/300
# 5/5 [==============================] - 1s 179ms/step - loss: 0.3926 - acc: 0.8826 - val_loss: 0.6512 - val_acc: 0.8300
# Epoch 160/300
# 5/5 [==============================] - 1s 179ms/step - loss: 0.3423 - acc: 0.8906 - val_loss: 0.6279 - val_acc: 0.8400
# Epoch 161/300
# 5/5 [==============================] - 1s 185ms/step - loss: 0.3380 - acc: 0.8932 - val_loss: 0.6850 - val_acc: 0.8350
# Epoch 162/300
# 5/5 [==============================] - 1s 188ms/step - loss: 0.3855 - acc: 0.8756 - val_loss: 0.7050 - val_acc: 0.8350
# Epoch 163/300
# 5/5 [==============================] - 1s 187ms/step - loss: 0.3852 - acc: 0.8808 - val_loss: 0.6667 - val_acc: 0.8450
# Epoch 164/300
# 5/5 [==============================] - 1s 177ms/step - loss: 0.3945 - acc: 0.8826 - val_loss: 0.6461 - val_acc: 0.8400
# Epoch 165/300
# 5/5 [==============================] - 1s 269ms/step - loss: 0.3634 - acc: 0.8835 - val_loss: 0.6736 - val_acc: 0.8350
# Epoch 166/300
# 5/5 [==============================] - 1s 299ms/step - loss: 0.3411 - acc: 0.8959 - val_loss: 0.6812 - val_acc: 0.8350
# Epoch 167/300
# 5/5 [==============================] - 1s 202ms/step - loss: 0.3254 - acc: 0.9047 - val_loss: 0.6680 - val_acc: 0.8350
# Epoch 168/300
# 5/5 [==============================] - 1s 187ms/step - loss: 0.3678 - acc: 0.8808 - val_loss: 0.6390 - val_acc: 0.8500
# Epoch 169/300
# 5/5 [==============================] - 1s 187ms/step - loss: 0.3924 - acc: 0.8808 - val_loss: 0.6189 - val_acc: 0.8450
# Epoch 170/300
# 5/5 [==============================] - 1s 192ms/step - loss: 0.3202 - acc: 0.9020 - val_loss: 0.6244 - val_acc: 0.8550
# Epoch 171/300
# 5/5 [==============================] - 1s 180ms/step - loss: 0.3695 - acc: 0.8738 - val_loss: 0.6633 - val_acc: 0.8550
# Epoch 172/300
# 5/5 [==============================] - 1s 187ms/step - loss: 0.3688 - acc: 0.8888 - val_loss: 0.6954 - val_acc: 0.8250
# Epoch 173/300
# 5/5 [==============================] - 1s 178ms/step - loss: 0.3673 - acc: 0.8826 - val_loss: 0.6841 - val_acc: 0.8500
# Epoch 174/300
# 5/5 [==============================] - 1s 194ms/step - loss: 0.3683 - acc: 0.8808 - val_loss: 0.6328 - val_acc: 0.8400
# Epoch 175/300
# 5/5 [==============================] - 1s 184ms/step - loss: 0.3309 - acc: 0.8994 - val_loss: 0.6188 - val_acc: 0.8350
# Epoch 176/300
# 5/5 [==============================] - 1s 184ms/step - loss: 0.3459 - acc: 0.8967 - val_loss: 0.6366 - val_acc: 0.8450
# Epoch 177/300
# 5/5 [==============================] - 1s 183ms/step - loss: 0.3432 - acc: 0.8950 - val_loss: 0.6740 - val_acc: 0.8350
# Epoch 178/300
# 5/5 [==============================] - 1s 288ms/step - loss: 0.3752 - acc: 0.8782 - val_loss: 0.6799 - val_acc: 0.8450
# Epoch 179/300
# 5/5 [==============================] - 1s 296ms/step - loss: 0.3734 - acc: 0.8826 - val_loss: 0.6849 - val_acc: 0.8450
# Epoch 180/300
# 5/5 [==============================] - 1s 196ms/step - loss: 0.3241 - acc: 0.8967 - val_loss: 0.6832 - val_acc: 0.8550
# Epoch 181/300
# 5/5 [==============================] - 1s 182ms/step - loss: 0.3583 - acc: 0.8959 - val_loss: 0.6376 - val_acc: 0.8650
# Epoch 182/300
# 5/5 [==============================] - 1s 181ms/step - loss: 0.3619 - acc: 0.8985 - val_loss: 0.6199 - val_acc: 0.8700
# Epoch 183/300
# 5/5 [==============================] - 1s 198ms/step - loss: 0.3218 - acc: 0.9047 - val_loss: 0.6142 - val_acc: 0.8750
# Epoch 184/300
# 5/5 [==============================] - 1s 193ms/step - loss: 0.3464 - acc: 0.8879 - val_loss: 0.6373 - val_acc: 0.8550
# Epoch 185/300
# 5/5 [==============================] - 1s 180ms/step - loss: 0.3419 - acc: 0.8932 - val_loss: 0.6384 - val_acc: 0.8650
# Epoch 186/300
# 5/5 [==============================] - 1s 187ms/step - loss: 0.3015 - acc: 0.9073 - val_loss: 0.6451 - val_acc: 0.8550
# Epoch 187/300
# 5/5 [==============================] - 1s 186ms/step - loss: 0.3187 - acc: 0.9188 - val_loss: 0.6435 - val_acc: 0.8600
# Epoch 188/300
# 5/5 [==============================] - 1s 179ms/step - loss: 0.3369 - acc: 0.8906 - val_loss: 0.6440 - val_acc: 0.8550
# Epoch 189/300
# 5/5 [==============================] - 1s 182ms/step - loss: 0.3164 - acc: 0.8959 - val_loss: 0.6660 - val_acc: 0.8450
# Epoch 190/300
# 5/5 [==============================] - 1s 180ms/step - loss: 0.2992 - acc: 0.9020 - val_loss: 0.6427 - val_acc: 0.8500
# Epoch 191/300
# 5/5 [==============================] - 1s 291ms/step - loss: 0.3066 - acc: 0.8985 - val_loss: 0.6609 - val_acc: 0.8650
# Epoch 192/300
# 5/5 [==============================] - 1s 297ms/step - loss: 0.3771 - acc: 0.8844 - val_loss: 0.6585 - val_acc: 0.8550
# Epoch 193/300
# 5/5 [==============================] - 1s 192ms/step - loss: 0.3182 - acc: 0.9020 - val_loss: 0.6594 - val_acc: 0.8550
# Epoch 194/300
# 5/5 [==============================] - 1s 180ms/step - loss: 0.3655 - acc: 0.8861 - val_loss: 0.6258 - val_acc: 0.8650
# Epoch 195/300
# 5/5 [==============================] - 1s 173ms/step - loss: 0.3315 - acc: 0.8959 - val_loss: 0.6210 - val_acc: 0.8650
# Epoch 196/300
# 5/5 [==============================] - 1s 178ms/step - loss: 0.3554 - acc: 0.8906 - val_loss: 0.6112 - val_acc: 0.8700
# Epoch 197/300
# 5/5 [==============================] - 1s 180ms/step - loss: 0.3126 - acc: 0.8967 - val_loss: 0.6134 - val_acc: 0.8550
# Epoch 198/300
# 5/5 [==============================] - 1s 177ms/step - loss: 0.3351 - acc: 0.8897 - val_loss: 0.6237 - val_acc: 0.8500
# Epoch 199/300
# 5/5 [==============================] - 1s 189ms/step - loss: 0.3584 - acc: 0.8861 - val_loss: 0.6312 - val_acc: 0.8350
# Epoch 200/300
# 5/5 [==============================] - 1s 192ms/step - loss: 0.3073 - acc: 0.8941 - val_loss: 0.6494 - val_acc: 0.8300
# Epoch 201/300
# 5/5 [==============================] - 1s 187ms/step - loss: 0.3312 - acc: 0.8950 - val_loss: 0.6199 - val_acc: 0.8400
# Epoch 202/300
# 5/5 [==============================] - 1s 191ms/step - loss: 0.3617 - acc: 0.8791 - val_loss: 0.5988 - val_acc: 0.8400
# Epoch 203/300
# 5/5 [==============================] - 1s 185ms/step - loss: 0.3099 - acc: 0.8923 - val_loss: 0.5937 - val_acc: 0.8500
# Epoch 204/300
# 5/5 [==============================] - 1s 293ms/step - loss: 0.3416 - acc: 0.8888 - val_loss: 0.5831 - val_acc: 0.8600
# Epoch 205/300
# 5/5 [==============================] - 1s 300ms/step - loss: 0.3193 - acc: 0.9003 - val_loss: 0.6140 - val_acc: 0.8650
# Epoch 206/300
# 5/5 [==============================] - 1s 178ms/step - loss: 0.3227 - acc: 0.8959 - val_loss: 0.6469 - val_acc: 0.8650
# Epoch 207/300
# 5/5 [==============================] - 1s 184ms/step - loss: 0.3414 - acc: 0.9038 - val_loss: 0.6301 - val_acc: 0.8650
# Epoch 208/300
# 5/5 [==============================] - 1s 190ms/step - loss: 0.3488 - acc: 0.8923 - val_loss: 0.6329 - val_acc: 0.8650
# Epoch 209/300
# 5/5 [==============================] - 1s 181ms/step - loss: 0.3284 - acc: 0.9029 - val_loss: 0.6217 - val_acc: 0.8700
# Epoch 210/300
# 5/5 [==============================] - 1s 181ms/step - loss: 0.3702 - acc: 0.8932 - val_loss: 0.6218 - val_acc: 0.8700
# Epoch 211/300
# 5/5 [==============================] - 1s 184ms/step - loss: 0.3111 - acc: 0.9029 - val_loss: 0.6305 - val_acc: 0.8600
# Epoch 212/300
# 5/5 [==============================] - 1s 178ms/step - loss: 0.3345 - acc: 0.9020 - val_loss: 0.6155 - val_acc: 0.8500
# Epoch 213/300
# 5/5 [==============================] - 1s 184ms/step - loss: 0.3091 - acc: 0.9011 - val_loss: 0.6243 - val_acc: 0.8450
# Epoch 214/300
# 5/5 [==============================] - 1s 189ms/step - loss: 0.3431 - acc: 0.8861 - val_loss: 0.6331 - val_acc: 0.8650
# Epoch 215/300
# 5/5 [==============================] - 2s 350ms/step - loss: 0.3627 - acc: 0.8959 - val_loss: 0.6300 - val_acc: 0.8600
# Epoch 216/300
# 5/5 [==============================] - 3s 730ms/step - loss: 0.3050 - acc: 0.9029 - val_loss: 0.6075 - val_acc: 0.8650
# Epoch 217/300
# 5/5 [==============================] - 1s 188ms/step - loss: 0.3230 - acc: 0.9029 - val_loss: 0.6119 - val_acc: 0.8750
# Epoch 218/300
# 5/5 [==============================] - 1s 183ms/step - loss: 0.3259 - acc: 0.9020 - val_loss: 0.6281 - val_acc: 0.8600
# Epoch 219/300
# 5/5 [==============================] - 1s 178ms/step - loss: 0.2876 - acc: 0.9126 - val_loss: 0.6479 - val_acc: 0.8400
# Epoch 220/300
# 5/5 [==============================] - 1s 191ms/step - loss: 0.2628 - acc: 0.9206 - val_loss: 0.6644 - val_acc: 0.8600
# Epoch 221/300
# 5/5 [==============================] - 1s 180ms/step - loss: 0.3405 - acc: 0.8976 - val_loss: 0.6889 - val_acc: 0.8600
# Epoch 222/300
# 5/5 [==============================] - 1s 175ms/step - loss: 0.2998 - acc: 0.9064 - val_loss: 0.6795 - val_acc: 0.8500
# Epoch 223/300
# 5/5 [==============================] - 1s 190ms/step - loss: 0.3342 - acc: 0.8976 - val_loss: 0.6668 - val_acc: 0.8400
# Epoch 224/300
# 5/5 [==============================] - 1s 179ms/step - loss: 0.2892 - acc: 0.9206 - val_loss: 0.6426 - val_acc: 0.8600
# Epoch 225/300
# 5/5 [==============================] - 1s 193ms/step - loss: 0.2985 - acc: 0.9056 - val_loss: 0.6937 - val_acc: 0.8400
# Epoch 226/300
# 5/5 [==============================] - 1s 186ms/step - loss: 0.3472 - acc: 0.8932 - val_loss: 0.6968 - val_acc: 0.8300
# Epoch 227/300
# 5/5 [==============================] - 1s 179ms/step - loss: 0.3362 - acc: 0.8994 - val_loss: 0.6681 - val_acc: 0.8500
# Epoch 228/300
# 5/5 [==============================] - 1s 306ms/step - loss: 0.3155 - acc: 0.9082 - val_loss: 0.6801 - val_acc: 0.8550
# Epoch 229/300
# 5/5 [==============================] - 2s 308ms/step - loss: 0.3419 - acc: 0.8932 - val_loss: 0.6588 - val_acc: 0.8550
# Epoch 230/300
# 5/5 [==============================] - 1s 180ms/step - loss: 0.2710 - acc: 0.9162 - val_loss: 0.6988 - val_acc: 0.8450
# Epoch 231/300
# 5/5 [==============================] - 1s 232ms/step - loss: 0.3359 - acc: 0.8967 - val_loss: 0.7390 - val_acc: 0.8350
# Epoch 232/300
# 5/5 [==============================] - 2s 306ms/step - loss: 0.3322 - acc: 0.8976 - val_loss: 0.7862 - val_acc: 0.8400
# Epoch 233/300
# 5/5 [==============================] - 1s 238ms/step - loss: 0.3056 - acc: 0.9056 - val_loss: 0.7280 - val_acc: 0.8450

# %%
from tensorflow.python.ops.math_ops import mean
import statistics
from statistics import mean


mean(history.history['acc'])
# Out:
# 0.7917716277387521

# %%
x_test = test_data.paper_id.to_numpy()
_, test_accuracy = gnn_model.evaluate(x=x_test, y=y_test, verbose=0)
print(f"Test accuracy: {round(test_accuracy * 100, 2)}%")
# Out:
# Test accuracy: 80.58%

# %%
fig, ax1 = plt.subplots(1, figsize=(4, 2))

ax1.plot(history.history["loss"])
ax1.plot(history.history["val_loss"])
ax1.legend(["Train", "Test"], loc="upper right")
ax1.set_xlabel("Epochs")
ax1.set_ylabel("Loss")
# Out:
# Text(0, 0.5, 'Loss')

# %%
y_pred=gnn_model.predict(x_test)
print(y_pred)
len(y_pred)
# Out:
# 43/43 [==============================] - 2s 26ms/step
# [[-3.6805172  -3.211684    2.3526905  ... -2.9541051  -1.4547809
#    1.5256861 ]
#  [-4.0133634  -1.8581713   7.009436   ... -4.2488728  -4.6284714
#   -0.6815301 ]
#  [ 0.9666578  -0.6884203   0.8231994  ... -3.0036423   0.6523061
#    5.597146  ]
#  ...
#  [ 0.95663095 -1.5564575   0.30655333 ... -2.9438648   2.1989644
#    5.7447376 ]
#  [-2.5135524  -1.5843983   5.035353   ... -3.1860127  -3.1912704
#   -0.21509962]
#  [-3.794191   -2.7417161   2.042966   ... -2.2876258  -2.5650992
#    0.07487477]]
# 1375

# %%
rounded_predictions=np.argmax(y_pred,axis=-1)
len(rounded_predictions)
# Out:
# 1375

# %%
for i in rounded_predictions:
  print(i)
# Out:
# 3
# 2
# 6
# 2
# 1
# 3
# 5
# 3
# 2
# 4
# 1
# 3
# 6
# 2
# 1
# 6
# 6
# 1
# 2
# 2
# 2
# 0
# 4
# 6
# 6
# 0
# 1
# 3
# 3
# 3
# 0
# 4
# 6
# 2
# 2
# 6
# 3
# 6
# 6
# 2
# 2
# 1
# 2
# 3
# 3
# 3
# 1
# 1
# 2
# 0
# 2
# 2
# 4
# 2
# 3
# 0
# 2
# 1
# 5
# 6
# 0
# 0
# 1
# 2
# 6
# 0
# 2
# 0
# 1
# 1
# 2
# 1
# 5
# 4
# 6
# 1
# 2
# 1
# 1
# 4
# 0
# 2
# 4
# 4
# 1
# 2
# 3
# 1
# 1
# 0
# 1
# 2
# 2
# 2
# 1
# 6
# 2
# 4
# 2
# 2
# 4
# 4
# 2
# 2
# 2
# 2
# 6
# 3
# 6
# 3
# 1
# 2
# 2
# 2
# 6
# 1
# 3
# 2
# 2
# 0
# 3
# 4
# 2
# 4
# 4
# 2
# 2
# 2
# 5
# 3
# 2
# 6
# 3
# 3
# 2
# 1
# 1
# 3
# 0
# 0
# 2
# 3
# 6
# 3
# 2
# 2
# 1
# 5
# 2
# 2
# 6
# 2
# 4
# 0
# 3
# 6
# 2
# 3
# 2
# 1
# 2
# 6
# 3
# 6
# 1
# 3
# 2
# 5
# 2
# 4
# 2
# 2
# 3
# 6
# 3
# 0
# 2
# 6
# 2
# 2
# 6
# 3
# 0
# 2
# 2
# 6
# 3
# 2
# 1
# 0
# 2
# 6
# 2
# 0
# 0
# 3
# 2
# 3
# 3
# 0
# 1
# 3
# 2
# 6
# 2
# 4
# 2
# 6
# 2
# 3
# 1
# 1
# 2
# 2
# 4
# 3
# 2
# 2
# 2
# 3
# 2
# 6
# 2
# 5
# 2
# 2
# 6
# 0
# 2
# 3
# 2
# 2
# 3
# 6
# 2
# 2
# 6
# 0
# 6
# 2
# 6
# 5
# 6
# 2
# 2
# 0
# 1
# 1
# 5
# 6
# 1
# 0
# 0
# 2
# 2
# 2
# 6
# 2
# 2
# 4
# 1
# 2
# 5
# 1
# 2
# 3
# 1
# 2
# 2
# 6
# 3
# 3
# 6
# 0
# 2
# 0
# 1
# 2
# 2
# 6
# 1
# 1
# 4
# 0
# 1
# 0
# 3
# 6
# 2
# 4
# 3
# 6
# 6
# 2
# 1
# 2
# 2
# 2
# 3
# 2
# 0
# 3
# 6
# 3
# 4
# 3
# 0
# 0
# 2
# 2
# 1
# 0
# 5
# 2
# 1
# 2
# 5
# 3
# 6
# 6
# 6
# 1
# 2
# 2
# 2
# 0
# 1
# 1
# 1
# 6
# 1
# 2
# 6
# 6
# 5
# 2
# 3
# 2
# 1
# 6
# 1
# 2
# 2
# 4
# 1
# 6
# 5
# 0
# 2
# 6
# 4
# 6
# 2
# 4
# 3
# 1
# 2
# 6
# 2
# 3
# 0
# 0
# 3
# 3
# 3
# 2
# 6
# 2
# 6
# 2
# 5
# 1
# 6
# 2
# 1
# 3
# 0
# 2
# 2
# 0
# 1
# 3
# 4
# 2
# 6
# 6
# 4
# 2
# 6
# 3
# 4
# 1
# 5
# 5
# 6
# 0
# 2
# 2
# 2
# 0
# 4
# 2
# 3
# 0
# 6
# 0
# 6
# 0
# 2
# 2
# 3
# 1
# 3
# 2
# 0
# 3
# 6
# 2
# 0
# 3
# 1
# 2
# 6
# 0
# 2
# 6
# 2
# 6
# 2
# 3
# 2
# 0
# 6
# 3
# 1
# 2
# 2
# 2
# 3
# 2
# 3
# 2
# 5
# 3
# 5
# 2
# 6
# 2
# 3
# 1
# 1
# 1
# 2
# 2
# 3
# 2
# 3
# 2
# 2
# 2
# 2
# 3
# 5
# 3
# 0
# 0
# 2
# 3
# 2
# 3
# 2
# 1
# 3
# 2
# 2
# 0
# 6
# 2
# 2
# 5
# 2
# 2
# 2
# 6
# 1
# 1
# 1
# 6
# 2
# 6
# 6
# 2
# 6
# 1
# 1
# 5
# 2
# 3
# 1
# 4
# 2
# 2
# 1
# 2
# 1
# 3
# 6
# 6
# 6
# 3
# 3
# 6
# 2
# 1
# 3
# 3
# 0
# 3
# 2
# 6
# 6
# 2
# 2
# 2
# 0
# 2
# 5
# 3
# 3
# 1
# 2
# 2
# 1
# 2
# 2
# 2
# 4
# 6
# 5
# 3
# 3
# 1
# 1
# 2
# 3
# 0
# 6
# 2
# 2
# 2
# 1
# 1
# 6
# 1
# 2
# 2
# 0
# 2
# 3
# 6
# 2
# 2
# 0
# 2
# 2
# 2
# 2
# 2
# 4
# 1
# 6
# 2
# 2
# 3
# 1
# 1
# 2
# 4
# 1
# 6
# 6
# 2
# 6
# 6
# 2
# 2
# 0
# 2
# 0
# 1
# 0
# 2
# 5
# 1
# 5
# 2
# 2
# 1
# 2
# 1
# 1
# 5
# 4
# 2
# 6
# 3
# 2
# 2
# 2
# 2
# 5
# 6
# 1
# 0
# 3
# 2
# 1
# 5
# 4
# 2
# 0
# 1
# 2
# 3
# 2
# 2
# 6
# 2
# 6
# 2
# 2
# 6
# 6
# 3
# 2
# 2
# 0
# 4
# 0
# 5
# 0
# 1
# 2
# 2
# 2
# 5
# 2
# 1
# 0
# 2
# 6
# 2
# 2
# 6
# 4
# 2
# 1
# 6
# 2
# 3
# 2
# 1
# 4
# 6
# 1
# 5
# 1
# 1
# 0
# 2
# 5
# 0
# 4
# 2
# 6
# 1
# 6
# 3
# 6
# 3
# 6
# 3
# 6
# 2
# 1
# 2
# 5
# 2
# 6
# 3
# 1
# 1
# 2
# 5
# 6
# 3
# 1
# 1
# 6
# 2
# 6
# 2
# 5
# 6
# 2
# 2
# 2
# 1
# 1
# 3
# 1
# 3
# 0
# 6
# 6
# 1
# 3
# 0
# 2
# 2
# 2
# 6
# 1
# 0
# 2
# 1
# 1
# 0
# 3
# 2
# 6
# 6
# 1
# 4
# 6
# 2
# 1
# 2
# 6
# 5
# 2
# 0
# 2
# 0
# 2
# 6
# 6
# 6
# 4
# 5
# 1
# 6
# 0
# 3
# 6
# 2
# 1
# 1
# 3
# 1
# 3
# 4
# 2
# 2
# 2
# 5
# 0
# 3
# 2
# 2
# 2
# 5
# 0
# 3
# 3
# 1
# 2
# 5
# 2
# 2
# 6
# 3
# 3
# 1
# 1
# 6
# 0
# 2
# 2
# 6
# 6
# 2
# 0
# 0
# 2
# 3
# 6
# 6
# 0
# 0
# 1
# 3
# 0
# 3
# 4
# 0
# 1
# 2
# 3
# 0
# 6
# 1
# 3
# 4
# 0
# 0
# 3
# 6
# 0
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 4
# 4
# 2
# 6
# 2
# 2
# 6
# 6
# 6
# 2
# 1
# 5
# 6
# 6
# 0
# 5
# 2
# 2
# 2
# 1
# 6
# 1
# 4
# 1
# 2
# 1
# 0
# 2
# 1
# 6
# 6
# 1
# 2
# 6
# 3
# 3
# 1
# 3
# 2
# 3
# 1
# 3
# 0
# 2
# 2
# 6
# 6
# 3
# 6
# 6
# 1
# 3
# 6
# 3
# 5
# 0
# 2
# 6
# 0
# 1
# 2
# 6
# 2
# 1
# 0
# 6
# 6
# 2
# 3
# 4
# 1
# 3
# 3
# 3
# 2
# 2
# 2
# 2
# 3
# 2
# 5
# 1
# 1
# 2
# 6
# 2
# 2
# 1
# 3
# 1
# 6
# 2
# 1
# 6
# 2
# 4
# 3
# 0
# 6
# 1
# 1
# 1
# 2
# 6
# 2
# 2
# 2
# 3
# 6
# 2
# 0
# 2
# 2
# 6
# 2
# 1
# 6
# 3
# 0
# 2
# 1
# 6
# 3
# 0
# 5
# 2
# 2
# 3
# 5
# 6
# 1
# 2
# 6
# 1
# 6
# 6
# 2
# 3
# 4
# 6
# 4
# 2
# 2
# 1
# 6
# 2
# 6
# 3
# 6
# 3
# 1
# 2
# 1
# 6
# 2
# 4
# 3
# 6
# 0
# 0
# 0
# 4
# 3
# 3
# 6
# 0
# 1
# 1
# 2
# 0
# 3
# 5
# 6
# 1
# 2
# 3
# 1
# 2
# 2
# 1
# 3
# 6
# 4
# 1
# 0
# 6
# 6
# 1
# 6
# 4
# 1
# 1
# 1
# 1
# 2
# 3
# 6
# 2
# 1
# 3
# 6
# 3
# 1
# 0
# 0
# 6
# 5
# 2
# 1
# 6
# 5
# 4
# 2
# 1
# 2
# 2
# 2
# 0
# 2
# 4
# 5
# 2
# 2
# 2
# 6
# 1
# 3
# 2
# 4
# 3
# 4
# 6
# 5
# 6
# 3
# 2
# 0
# 6
# 2
# 2
# 5
# 2
# 0
# 6
# 2
# 1
# 1
# 2
# 3
# 2
# 6
# 4
# 2
# 6
# 2
# 2
# 4
# 3
# 2
# 2
# 2
# 2
# 1
# 3
# 6
# 4
# 6
# 0
# 5
# 2
# 1
# 5
# 6
# 6
# 3
# 0
# 4
# 2
# 0
# 0
# 6
# 0
# 0
# 0
# 1
# 2
# 6
# 3
# 5
# 5
# 3
# 0
# 0
# 6
# 1
# 3
# 5
# 5
# 2
# 0
# 6
# 6
# 4
# 1
# 3
# 2
# 1
# 3
# 0
# 2
# 4
# 1
# 2
# 6
# 1
# 6
# 6
# 3
# 6
# 4
# 3
# 4
# 4
# 3
# 2
# 5
# 2
# 0
# 4
# 2
# 6
# 5
# 2
# 3
# 0
# 3
# 6
# 1
# 0
# 1
# 1
# 2
# 0
# 6
# 6
# 2
# 1
# 2
# 3
# 3
# 1
# 1
# 3
# 2
# 1
# 6
# 2
# 1
# 2
# 2
# 2
# 2
# 2
# 1
# 1
# 2
# 0
# 1
# 3
# 0
# 3
# 6
# 1
# 4
# 2
# 3
# 5
# 0
# 1
# 4
# 3
# 1
# 2
# 2
# 3
# 3
# 3
# 1
# 6
# 2
# 4
# 1
# 1
# 1
# 2
# 0
# 3
# 2
# 2
# 2
# 3
# 6
# 3
# 2
# 0
# 3
# 2
# 2
# 3
# 2
# 1
# 2
# 6
# 3
# 2
# 3
# 6
# 0
# 6
# 5
# 1
# 3
# 6
# 6
# 1
# 6
# 0
# 6
# 1
# 0
# 6
# 1
# 5
# 2
# 0
# 2
# 6
# 3
# 4
# 2
# 0
# 2
# 5
# 6
# 2
# 0
# 6
# 4
# 2
# 2
# 2
# 0
# 5
# 6
# 3
# 0
# 4
# 2
# 2
# 2
# 2
# 4
# 1
# 2
# 3
# 5
# 2
# 2
# 4
# 6
# 2
# 2
# 4
# 2
# 4
# 2
# 3
# 2
# 1
# 3
# 1
# 6
# 5
# 2
# 2
# 2
# 6
# 2
# 2
# 2
# 0
# 2
# 5
# 0
# 6
# 2
# 1
# 6
# 2
# 4
# 1
# 6
# 0
# 5
# 1
# 0
# 1
# 6
# 2
# 0
# 4
# 4
# 2
# 2
# 3
# 3
# 0
# 3
# 6
# 3
# 6
# 2
# 3
# 2
# 3
# 1
# 4
# 2
# 1
# 5
# 5
# 0
# 2
# 2
# 2
# 6
# 0
# 2
# 2
# 6
# 6
# 3
# 0
# 3
# 4
# 2
# 6
# 2
# 3

# %% [markdown]
# #Classification report

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,rounded_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.75      0.75       146
#            1       0.86      0.92      0.89       198
#            2       0.86      0.86      0.86       425
#            3       0.88      0.79      0.83       225
#            4       0.92      0.63      0.74       123
#            5       0.76      0.65      0.70        85
#            6       0.60      0.82      0.69       173
#
#     accuracy                           0.81      1375
#    macro avg       0.80      0.77      0.78      1375
# weighted avg       0.82      0.81      0.81      1375

# %%
# %matplotlib inline
from sklearn.metrics import confusion_matrix
import itertools
import matplotlib.pyplot as plt

# %%
cm=confusion_matrix(y_true=y_test,y_pred=rounded_predictions)

# %%
def plot_confusion_matrix(cm,classes,normalize=False,title='Confusion_matrix,cmap=plt.cm.blues'):
  plt.imshow(cm,interpolation='nearest',cmap=cmap)
  plot.title(title)
  plt.colorbar()
  tick_marks=np.arrange(len(classes))
  plt.xticks(tick_marks,classes,rotation=45)
  plt.ytick(tick_marks,classes)

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
cnf_matrix = confusion_matrix(y_test, rounded_predictions, labels=[0,1,2,3,4,5,6,7])
np.set_printoptions(precision=2)

# Plot confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=['0','1','2','3','4','5','6'],normalize= False,  title='Confusion matrix')
# Out:
# Confusion matrix, without normalization
# [[109   5   4   1   1   8  18   0]
#  [  1 182   5   3   3   1   3   0]
#  [  4   4 366  12   2   1  36   0]
#  [  5   0  22 178   1   1  18   0]
#  [  5  17  14   6  77   1   3   0]
#  [ 11   0   4   0   0  55  15   0]
#  [ 11   3  11   2   0   5 141   0]
#  [  0   0   0   0   0   0   0   0]]

# %%
sensitivity = cm[0,0]/(cm[0,0]+cm[0,1])
print(sensitivity)
# Out:
# 0.956140350877193

# %%
specificity = cm[1,1]/(cm[1,0]+cm[1,1])
print('Specificity : ', specificity)
# Out:
# Specificity :  0.994535519125683
